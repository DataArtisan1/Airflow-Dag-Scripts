# %% [markdown]
# Scenario 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Scenario 2: No files Found

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
